# %%
import pandas as pd

# %%
Internal = pd.read_excel('Internal.xlsx', index_col=None, header=None)

# %%
Internal
# Out:
#      0       1           2    3    4                      5          6    7   \
# 0    NO     號 碼        線  徑   顏色  長 度                   端  子    對 應 位 置  NaN
# 1     1      PE      5.5*1C  Y/G  NaN    RNB5-5\n(5.5-5R)+綠套         箱體  NaN
# 2     2      PE      5.5*1C  Y/G  NaN    RNB5-5\n(5.5-5R)+綠套         門板  NaN
# 3     3      PE      3.5*1C  Y/G  NaN   RNBS3-5\n(3.5-5R)+綠套  VFD\n(PE)    正
# 4     4      PE      2.0*1C  Y/G  NaN         E2512\n(2-長TE)         G1    反
# ..  ...     ...         ...  ...  ...                    ...        ...  ...
# 73   73     N24      0.5*3C    黑  NaN      E0512L\n(0.5-長TE)        TB1  NaN
# 74  NaN     X00         NaN    白  NaN  SNBS1-3.7\n(1.25-3YS)        EMO  NaN
# 75  NaN     EMO         NaN    紅  NaN  SNBS1-3.7\n(1.25-3YS)        EMO  NaN
# 76   74  VFD_D+  22AWG\n*1P    紅  NaN       E0508L\n(0.5-TE)    VFD(D+)  NaN
# 77  NaN  VFD_D-         NaN    黑  NaN       E0508L\n(0.5-TE)    VFD(D-)  NaN
#
# ...
